# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import requests
import json
from pprint import pprint
from api_keys import weather_api_key
import citipy as citipy
import numpy as np
import time
import scipy.stats as st
from scipy.stats import linregress

from citipy import citipy
import datetime
import seaborn as sns

api_key = weather_api_key

# Output File (CSV)
#output_data_file = "output_data/cities.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List to hold cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add to cities list
    if city not in cities:
        cities.append(city)

# Print the city count 
len(cities)
# Out:
# 592

# %%
# create the dataframe to hold city info

city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#print("Beginning Data Retrieval ")
#print("-----------------------------")


base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={api_key}&units={units}&q="


# For city name in cities 
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 100:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

#print("-----------------------------")
#print("Data Retrieval Complete")
#print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 : punta arenas
# City not found. Skipping...
# Processing Record 2 of Set 1 : bluff
# Processing Record 3 of Set 1 : lebu
# Processing Record 4 of Set 1 : hilo
# Processing Record 5 of Set 1 : rikitea
# Processing Record 6 of Set 1 : nizhnyaya tavda
# Processing Record 7 of Set 1 : fairbanks
# Processing Record 8 of Set 1 : coihaique
# Processing Record 9 of Set 1 : solnechnyy
# Processing Record 10 of Set 1 : barentu
# Processing Record 11 of Set 1 : esmeraldas
# Processing Record 12 of Set 1 : vaini
# Processing Record 13 of Set 1 : ponta do sol
# Processing Record 14 of Set 1 : georgetown
# Processing Record 15 of Set 1 : erenhot
# Processing Record 16 of Set 1 : barrow
# Processing Record 17 of Set 1 : progreso
# City not found. Skipping...
# Processing Record 18 of Set 1 : srednekolymsk
# City not found. Skipping...
# Processing Record 19 of Set 1 : bredasdorp
# Processing Record 20 of Set 1 : atuona
# Processing Record 21 of Set 1 : busselton
# Processing Record 22 of Set 1 : mar del plata
# Processing Record 23 of Set 1 : mbuguni
# Processing Record 24 of Set 1 : dikson
# Processing Record 25 of Set 1 : siniscola
# Processing Record 26 of Set 1 : wanxian
# Processing Record 27 of Set 1 : sabla
# Processing Record 28 of Set 1 : bengkulu
# Processing Record 29 of Set 1 : tiksi
# Processing Record 30 of Set 1 : hermanus
# Processing Record 31 of Set 1 : hue
# Processing Record 32 of Set 1 : malakal
# Processing Record 33 of Set 1 : kaitangata
# City not found. Skipping...
# Processing Record 34 of Set 1 : mahanoro
# Processing Record 35 of Set 1 : tuktoyaktuk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 1 : paamiut
# Processing Record 37 of Set 1 : bambous virieux
# Processing Record 38 of Set 1 : itarema
# Processing Record 39 of Set 1 : kargopol
# Processing Record 40 of Set 1 : warrnambool
# Processing Record 41 of Set 1 : kapaa
# Processing Record 42 of Set 1 : katsuura
# Processing Record 43 of Set 1 : ushuaia
# Processing Record 44 of Set 1 : ust-maya
# City not found. Skipping...
# Processing Record 45 of Set 1 : lata
# Processing Record 46 of Set 1 : surt
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set 1 : teahupoo
# City not found. Skipping...
# Processing Record 48 of Set 1 : avarua
# Processing Record 49 of Set 1 : marsabit
# City not found. Skipping...
# Processing Record 50 of Set 1 : arraial do cabo
# Processing Record 51 of Set 1 : khandyga
# Processing Record 52 of Set 1 : port elizabeth
# Processing Record 53 of Set 1 : hobart
# Processing Record 54 of Set 1 : nanortalik
# Processing Record 55 of Set 1 : new norfolk
# Processing Record 56 of Set 1 : bethel
# Processing Record 57 of Set 1 : verkhoyansk
# Processing Record 58 of Set 1 : olafsvik
# Processing Record 59 of Set 1 : los llanos de aridane
# Processing Record 60 of Set 1 : qaqortoq
# Processing Record 61 of Set 1 : kodiak
# Processing Record 62 of Set 1 : airai
# Processing Record 63 of Set 1 : cabo san lucas
# City not found. Skipping...
# Processing Record 64 of Set 1 : cuajinicuilapa
# Processing Record 65 of Set 1 : souillac
# Processing Record 66 of Set 1 : bandrele
# Processing Record 67 of Set 1 : epe
# Processing Record 68 of Set 1 : adelaide
# Processing Record 69 of Set 1 : albany
# Processing Record 70 of Set 1 : half moon bay
# City not found. Skipping...
# Processing Record 71 of Set 1 : yurimaguas
# Processing Record 72 of Set 1 : jamestown
# Processing Record 73 of Set 1 : labuhan
# Processing Record 74 of Set 1 : fereydunshahr
# Processing Record 75 of Set 1 : mahebourg
# Processing Record 76 of Set 1 : salalah
# City not found. Skipping...
# Processing Record 77 of Set 1 : mount pleasant
# Processing Record 78 of Set 1 : yulara
# City not found. Skipping...
# Processing Record 79 of Set 1 : chor
# City not found. Skipping...
# Processing Record 80 of Set 1 : shimoda
# Processing Record 81 of Set 1 : kavieng
# Processing Record 82 of Set 1 : toamasina
# Processing Record 83 of Set 1 : palmas
# Processing Record 84 of Set 1 : vestmannaeyjar
# City not found. Skipping...
# Processing Record 85 of Set 1 : fortuna
# Processing Record 86 of Set 1 : carnarvon
# Processing Record 87 of Set 1 : laguna
# Processing Record 88 of Set 1 : basco
# Processing Record 89 of Set 1 : khatanga
# Processing Record 90 of Set 1 : salta
# Processing Record 91 of Set 1 : washougal
# City not found. Skipping...
# Processing Record 92 of Set 1 : merke
# Processing Record 93 of Set 1 : bud
# Processing Record 94 of Set 1 : zenzeli
# Processing Record 95 of Set 1 : muros
# Processing Record 96 of Set 1 : namatanai
# Processing Record 97 of Set 1 : ilulissat
# Processing Record 98 of Set 1 : ahipara
# Processing Record 99 of Set 1 : pisco
# Processing Record 100 of Set 1 : ostrovnoy
# Processing Record 101 of Set 1 : tuma
# City not found. Skipping...
# Processing Record 0 of Set 2 : bathsheba
# Processing Record 1 of Set 2 : butaritari
# Processing Record 2 of Set 2 : punta gorda
# Processing Record 3 of Set 2 : stornoway
# Processing Record 4 of Set 2 : shizunai
# Processing Record 5 of Set 2 : chuy
# Processing Record 6 of Set 2 : nisia floresta
# Processing Record 7 of Set 2 : antofagasta
# Processing Record 8 of Set 2 : wajima
# Processing Record 9 of Set 2 : port-gentil
# Processing Record 10 of Set 2 : upernavik
# Processing Record 11 of Set 2 : mataura
# Processing Record 12 of Set 2 : amga
# City not found. Skipping...
# Processing Record 13 of Set 2 : port blair
# Processing Record 14 of Set 2 : dapitan
# Processing Record 15 of Set 2 : puerto ayora
# Processing Record 16 of Set 2 : east london
# Processing Record 17 of Set 2 : santa cruz cabralia
# Processing Record 18 of Set 2 : inhambane
# Processing Record 19 of Set 2 : qaanaaq
# Processing Record 20 of Set 2 : jiwani
# Processing Record 21 of Set 2 : beloha
# Processing Record 22 of Set 2 : esperance
# Processing Record 23 of Set 2 : locri
# City not found. Skipping...
# Processing Record 24 of Set 2 : cidreira
# Processing Record 25 of Set 2 : kayan
# Processing Record 26 of Set 2 : castro
# Processing Record 27 of Set 2 : ponta delgada
# Processing Record 28 of Set 2 : cairns
# Processing Record 29 of Set 2 : nelson bay
# Processing Record 30 of Set 2 : illapel
# Processing Record 31 of Set 2 : saskylakh
# Processing Record 32 of Set 2 : mogadishu
# City not found. Skipping...
# Processing Record 33 of Set 2 : adrar
# Processing Record 34 of Set 2 : beni suef
# Processing Record 35 of Set 2 : wageningen
# Processing Record 36 of Set 2 : saint-philippe
# Processing Record 37 of Set 2 : salina
# City not found. Skipping...
# Processing Record 38 of Set 2 : tambura
# Processing Record 39 of Set 2 : manta
# Processing Record 40 of Set 2 : henties bay
# Processing Record 41 of Set 2 : tuatapere
# Processing Record 42 of Set 2 : manokwari
# Processing Record 43 of Set 2 : kruisfontein
# Processing Record 44 of Set 2 : ribeira grande
# Processing Record 45 of Set 2 : talnakh
# Processing Record 46 of Set 2 : tasiilaq
# Processing Record 47 of Set 2 : pimentel
# Processing Record 48 of Set 2 : caravelas
# City not found. Skipping...
# Processing Record 49 of Set 2 : kenai
# Processing Record 50 of Set 2 : kerouane
# Processing Record 51 of Set 2 : cape town
# Processing Record 52 of Set 2 : guerrero negro
# Processing Record 53 of Set 2 : ancud
# Processing Record 54 of Set 2 : victoria
# Processing Record 55 of Set 2 : chokurdakh
# Processing Record 56 of Set 2 : trapani
# Processing Record 57 of Set 2 : turbat
# City not found. Skipping...
# Processing Record 58 of Set 2 : bulancak
# Processing Record 59 of Set 2 : sechura
# Processing Record 60 of Set 2 : otjimbingwe
# Processing Record 61 of Set 2 : vanimo
# Processing Record 62 of Set 2 : batemans bay
# Processing Record 63 of Set 2 : pilar
# Processing Record 64 of Set 2 : iquitos
# Processing Record 65 of Set 2 : yellowknife
# Processing Record 66 of Set 2 : marsh harbour
# Processing Record 67 of Set 2 : bintulu
# Processing Record 68 of Set 2 : saint anthony
# Processing Record 69 of Set 2 : barranca
# Processing Record 70 of Set 2 : rio gallegos
# Processing Record 71 of Set 2 : penzance
# Processing Record 72 of Set 2 : monjaras
# Processing Record 73 of Set 2 : sinnamary
# Processing Record 74 of Set 2 : dunedin
# City not found. Skipping...
# Processing Record 75 of Set 2 : boa vista
# Processing Record 76 of Set 2 : clyde river
# Processing Record 77 of Set 2 : okha
# Processing Record 78 of Set 2 : dingle
# Processing Record 79 of Set 2 : ambulu
# Processing Record 80 of Set 2 : kalabo
# Processing Record 81 of Set 2 : lagoa
# Processing Record 82 of Set 2 : pemangkat
# Processing Record 83 of Set 2 : dolzhanskaya
# City not found. Skipping...
# Processing Record 84 of Set 2 : lazaro cardenas
# Processing Record 85 of Set 2 : longyearbyen
# Processing Record 86 of Set 2 : lagos
# Processing Record 87 of Set 2 : gelibolu
# Processing Record 88 of Set 2 : nizhniy tsasuchey
# City not found. Skipping...
# Processing Record 89 of Set 2 : vardo
# Processing Record 90 of Set 2 : hamilton
# Processing Record 91 of Set 2 : vila
# Processing Record 92 of Set 2 : bafoulabe
# Processing Record 93 of Set 2 : vilcun
# Processing Record 94 of Set 2 : pangnirtung
# Processing Record 95 of Set 2 : luderitz
# Processing Record 96 of Set 2 : dafeng
# Processing Record 97 of Set 2 : hervey bay
# Processing Record 98 of Set 2 : sao jose da coroa grande
# Processing Record 99 of Set 2 : torbay
# Processing Record 100 of Set 2 : tongling
# Processing Record 101 of Set 2 : bria
# Processing Record 0 of Set 3 : codrington
# Processing Record 1 of Set 3 : sisimiut
# Processing Record 2 of Set 3 : mombasa
# Processing Record 3 of Set 3 : narsaq
# Processing Record 4 of Set 3 : port alfred
# Processing Record 5 of Set 3 : lavrentiya
# Processing Record 6 of Set 3 : kerema
# Processing Record 7 of Set 3 : faanui
# Processing Record 8 of Set 3 : klaksvik
# Processing Record 9 of Set 3 : dossor
# Processing Record 10 of Set 3 : pevek
# Processing Record 11 of Set 3 : the valley
# Processing Record 12 of Set 3 : lamu
# Processing Record 13 of Set 3 : kununurra
# Processing Record 14 of Set 3 : cabrobo
# Processing Record 15 of Set 3 : kalmunai
# Processing Record 16 of Set 3 : wilkie
# Processing Record 17 of Set 3 : chegdomyn
# Processing Record 18 of Set 3 : cherskiy
# Processing Record 19 of Set 3 : hounde
# Processing Record 20 of Set 3 : cayenne
# City not found. Skipping...
# Processing Record 21 of Set 3 : qui nhon
# Processing Record 22 of Set 3 : north bend
# Processing Record 23 of Set 3 : dwarka
# Processing Record 24 of Set 3 : roald
# Processing Record 25 of Set 3 : diamantino
# Processing Record 26 of Set 3 : straumen
# Processing Record 27 of Set 3 : fonte boa
# Processing Record 28 of Set 3 : liberal
# Processing Record 29 of Set 3 : choctaw
# Processing Record 30 of Set 3 : dakar
# Processing Record 31 of Set 3 : port lincoln
# Processing Record 32 of Set 3 : kuliyapitiya
# Processing Record 33 of Set 3 : akdepe
# Processing Record 34 of Set 3 : padang
# Processing Record 35 of Set 3 : zyryanka
# Processing Record 36 of Set 3 : wabag
# Processing Record 37 of Set 3 : tungor
# Processing Record 38 of Set 3 : lusambo
# Processing Record 39 of Set 3 : puerto maldonado
# Processing Record 40 of Set 3 : taebla
# Processing Record 41 of Set 3 : grand gaube
# Processing Record 42 of Set 3 : vanavara
# Processing Record 43 of Set 3 : vostok
# Processing Record 44 of Set 3 : veraval
# Processing Record 45 of Set 3 : nador
# Processing Record 46 of Set 3 : san patricio
# Processing Record 47 of Set 3 : svetlyy
# Processing Record 48 of Set 3 : pryshyb
# Processing Record 49 of Set 3 : thompson
# Processing Record 50 of Set 3 : dudinka
# Processing Record 51 of Set 3 : portobelo
# City not found. Skipping...
# Processing Record 52 of Set 3 : oneida
# Processing Record 53 of Set 3 : petropavlovsk-kamchatskiy
# Processing Record 54 of Set 3 : kavaratti
# Processing Record 55 of Set 3 : abu samrah
# Processing Record 56 of Set 3 : fjerritslev
# Processing Record 57 of Set 3 : provideniya
# Processing Record 58 of Set 3 : alofi
# Processing Record 59 of Set 3 : acapulco
# Processing Record 60 of Set 3 : margate
# Processing Record 61 of Set 3 : davidson
# City not found. Skipping...
# Processing Record 62 of Set 3 : portland
# Processing Record 63 of Set 3 : flinders
# Processing Record 64 of Set 3 : nishihara
# Processing Record 65 of Set 3 : iracoubo
# Processing Record 66 of Set 3 : novo aripuana
# Processing Record 67 of Set 3 : geraldton
# Processing Record 68 of Set 3 : belmonte
# Processing Record 69 of Set 3 : meaford
# City not found. Skipping...
# Processing Record 70 of Set 3 : rabo de peixe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 71 of Set 3 : weston
# Processing Record 72 of Set 3 : camacha
# Processing Record 73 of Set 3 : hirara
# Processing Record 74 of Set 3 : haines junction
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 75 of Set 3 : husavik
# Processing Record 76 of Set 3 : hithadhoo
# Processing Record 77 of Set 3 : plyussa
# Processing Record 78 of Set 3 : egvekinot
# Processing Record 79 of Set 3 : constitucion
# Processing Record 80 of Set 3 : vao
# Processing Record 81 of Set 3 : buala
# Processing Record 82 of Set 3 : golden gate
# Processing Record 83 of Set 3 : vila franca do campo
# Processing Record 84 of Set 3 : fevik
# Processing Record 85 of Set 3 : chiredzi
# Processing Record 86 of Set 3 : joshimath
# Processing Record 87 of Set 3 : maputo
# Processing Record 88 of Set 3 : leningradskiy
# Processing Record 89 of Set 3 : verkhnyaya inta
# Processing Record 90 of Set 3 : iqaluit
# Processing Record 91 of Set 3 : dalbandin
# Processing Record 92 of Set 3 : yerbogachen
# Processing Record 93 of Set 3 : tura
# Processing Record 94 of Set 3 : conde
# Processing Record 95 of Set 3 : avera
# Processing Record 96 of Set 3 : kumluca
# Processing Record 97 of Set 3 : birao
# Processing Record 98 of Set 3 : te anau
# City not found. Skipping...
# Processing Record 99 of Set 3 : san antonio
# Processing Record 100 of Set 3 : aksu
# City not found. Skipping...
# Processing Record 101 of Set 3 : mezhdurechensk
# Processing Record 0 of Set 4 : westport
# Processing Record 1 of Set 4 : soderhamn
# Processing Record 2 of Set 4 : mahibadhoo
# Processing Record 3 of Set 4 : tomari
# Processing Record 4 of Set 4 : kidal
# Processing Record 5 of Set 4 : port augusta
# Processing Record 6 of Set 4 : mount gambier
# Processing Record 7 of Set 4 : itatiba
# Processing Record 8 of Set 4 : uspenskaya
# City not found. Skipping...
# Processing Record 9 of Set 4 : road town
# Processing Record 10 of Set 4 : yangjiang
# Processing Record 11 of Set 4 : aasiaat
# Processing Record 12 of Set 4 : nikolskoye
# Processing Record 13 of Set 4 : vicuna
# Processing Record 14 of Set 4 : oktyabrskiy
# Processing Record 15 of Set 4 : tabas
# Processing Record 16 of Set 4 : aklavik
# Processing Record 17 of Set 4 : mehamn
# Processing Record 18 of Set 4 : campbell river
# Processing Record 19 of Set 4 : mandapeta
# Processing Record 20 of Set 4 : rafsanjan
# Processing Record 21 of Set 4 : viedma
# Processing Record 22 of Set 4 : chicama
# Processing Record 23 of Set 4 : tutoia
# Processing Record 24 of Set 4 : kutum
# Processing Record 25 of Set 4 : batagay-alyta
# Processing Record 26 of Set 4 : mabaruma
# Processing Record 27 of Set 4 : beringovskiy
# Processing Record 28 of Set 4 : kushima
# Processing Record 29 of Set 4 : le port
# Processing Record 30 of Set 4 : nemuro
# Processing Record 31 of Set 4 : llanera
# Processing Record 32 of Set 4 : severo-kurilsk
# Processing Record 33 of Set 4 : tecoanapa
# Processing Record 34 of Set 4 : fukue
# Processing Record 35 of Set 4 : halifax
# Processing Record 36 of Set 4 : saint george
# Processing Record 37 of Set 4 : montecorvino rovella
# Processing Record 38 of Set 4 : pandan
# Processing Record 39 of Set 4 : kinwat
# Processing Record 40 of Set 4 : dumas
# Processing Record 41 of Set 4 : yarensk
# Processing Record 42 of Set 4 : nabire
# Processing Record 43 of Set 4 : manono
# Processing Record 44 of Set 4 : solone
# Processing Record 45 of Set 4 : yongchang
# Processing Record 46 of Set 4 : anloga
# Processing Record 47 of Set 4 : pacific grove
# Processing Record 48 of Set 4 : conceicao da barra
# Processing Record 49 of Set 4 : naron
# Processing Record 50 of Set 4 : powell river
# Processing Record 51 of Set 4 : sitka
# Processing Record 52 of Set 4 : marawi
# Processing Record 53 of Set 4 : turukhansk
# Processing Record 54 of Set 4 : hay river
# Processing Record 55 of Set 4 : biak
# Processing Record 56 of Set 4 : emilio carranza
# Processing Record 57 of Set 4 : makinsk
# Processing Record 58 of Set 4 : chapais
# Processing Record 59 of Set 4 : bandarbeyla
# Processing Record 60 of Set 4 : sao filipe
# Processing Record 61 of Set 4 : aranos
# Processing Record 62 of Set 4 : udachnyy
# Processing Record 63 of Set 4 : misratah
# Processing Record 64 of Set 4 : lock haven
# Processing Record 65 of Set 4 : vernon
# Processing Record 66 of Set 4 : thinadhoo
# Processing Record 67 of Set 4 : nagato
# Processing Record 68 of Set 4 : luxemburg
# Processing Record 69 of Set 4 : hasaki
# Processing Record 70 of Set 4 : ialibu
# Processing Record 71 of Set 4 : zhangye
# Processing Record 72 of Set 4 : bjornevatn
# Processing Record 73 of Set 4 : roros
# Processing Record 74 of Set 4 : lukovetskiy
# Processing Record 75 of Set 4 : saint-louis
# Processing Record 76 of Set 4 : chara
# Processing Record 77 of Set 4 : richards bay
# City not found. Skipping...
# Processing Record 78 of Set 4 : megion
# Processing Record 79 of Set 4 : staryy nadym
# Processing Record 80 of Set 4 : kyaukse
# Processing Record 81 of Set 4 : byron bay
# Processing Record 82 of Set 4 : nur
# Processing Record 83 of Set 4 : lamar
# Processing Record 84 of Set 4 : chambas
# Processing Record 85 of Set 4 : ketchikan
# Processing Record 86 of Set 4 : hualmay
# Processing Record 87 of Set 4 : havre-saint-pierre
# Processing Record 88 of Set 4 : sumbawanga
# Processing Record 89 of Set 4 : kudat
# Processing Record 90 of Set 4 : khorixas
# Processing Record 91 of Set 4 : kaduqli
# Processing Record 92 of Set 4 : mbigou
# Processing Record 93 of Set 4 : gunjur
# Processing Record 94 of Set 4 : eyl
# Processing Record 95 of Set 4 : tigil
# Processing Record 96 of Set 4 : hovd
# City not found. Skipping...
# Processing Record 97 of Set 4 : sao joao da barra
# Processing Record 98 of Set 4 : nome
# Processing Record 99 of Set 4 : togul
# Processing Record 100 of Set 4 : senneterre
# Processing Record 101 of Set 4 : rafraf
# Processing Record 0 of Set 5 : minggang
# Processing Record 1 of Set 5 : deputatskiy
# Processing Record 2 of Set 5 : mount isa
# Processing Record 3 of Set 5 : xiuyan
# Processing Record 4 of Set 5 : changtu
# Processing Record 5 of Set 5 : newport
# Processing Record 6 of Set 5 : okhotsk
# Processing Record 7 of Set 5 : khasan
# City not found. Skipping...
# Processing Record 8 of Set 5 : berlevag
# Processing Record 9 of Set 5 : guanambi
# Processing Record 10 of Set 5 : tual
# Processing Record 11 of Set 5 : akyab
# Processing Record 12 of Set 5 : waipawa
# Processing Record 13 of Set 5 : chaman
# City not found. Skipping...
# Processing Record 14 of Set 5 : dinghai
# Processing Record 15 of Set 5 : cabedelo
# Processing Record 16 of Set 5 : cascais
# Processing Record 17 of Set 5 : cockburn town
# Processing Record 18 of Set 5 : barra do corda
# Processing Record 19 of Set 5 : port hardy
# Processing Record 20 of Set 5 : taltal
# Processing Record 21 of Set 5 : port macquarie
# Processing Record 22 of Set 5 : grand forks
# Processing Record 23 of Set 5 : vrangel
# Processing Record 24 of Set 5 : apacilagua
# Processing Record 25 of Set 5 : miquelon
# Processing Record 26 of Set 5 : nefteyugansk
# Processing Record 27 of Set 5 : konyshevka
# Processing Record 28 of Set 5 : inirida
# Processing Record 29 of Set 5 : mbandaka
# Processing Record 30 of Set 5 : kargasok
# Processing Record 31 of Set 5 : fort nelson
# Processing Record 32 of Set 5 : axim
# Processing Record 33 of Set 5 : ginda
# Processing Record 34 of Set 5 : pekan
# Processing Record 35 of Set 5 : uppsala
# Processing Record 36 of Set 5 : sioux lookout
# Processing Record 37 of Set 5 : hoshangabad
# Processing Record 38 of Set 5 : moose factory
# Processing Record 39 of Set 5 : caraquet
# Processing Record 40 of Set 5 : luanda
# Processing Record 41 of Set 5 : ivanava
# Processing Record 42 of Set 5 : buraydah
# Processing Record 43 of Set 5 : tautira
# Processing Record 44 of Set 5 : carndonagh
# Processing Record 45 of Set 5 : wahiawa
# Processing Record 46 of Set 5 : kudahuvadhoo
# Processing Record 47 of Set 5 : altamira
# Processing Record 48 of Set 5 : sovetsk
# Processing Record 49 of Set 5 : flin flon
# Processing Record 50 of Set 5 : naryan-mar
# Processing Record 51 of Set 5 : teofilo otoni
# Processing Record 52 of Set 5 : broome
# Processing Record 53 of Set 5 : morgan city
# Processing Record 54 of Set 5 : antsohihy
# Processing Record 55 of Set 5 : guabito
# Processing Record 56 of Set 5 : bayji
# Processing Record 57 of Set 5 : bambanglipuro
# Processing Record 58 of Set 5 : isangel
# Processing Record 59 of Set 5 : komsomolskiy
# Processing Record 60 of Set 5 : umm lajj
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 61 of Set 5 : la rioja
# Processing Record 62 of Set 5 : eirunepe
# Processing Record 63 of Set 5 : vestmanna
# Processing Record 64 of Set 5 : usinsk
# Processing Record 65 of Set 5 : ramona
# Processing Record 66 of Set 5 : champerico
# Processing Record 67 of Set 5 : emerald
# Processing Record 68 of Set 5 : fomboni
# Processing Record 69 of Set 5 : dicabisagan
# City not found. Skipping...
# Processing Record 70 of Set 5 : olinda
# Processing Record 71 of Set 5 : ust-karsk
# Processing Record 72 of Set 5 : quatre cocos
# Processing Record 73 of Set 5 : manakara
# Processing Record 74 of Set 5 : atambua
# Processing Record 75 of Set 5 : naze
# Processing Record 76 of Set 5 : innisfail
# City not found. Skipping...
# Processing Record 77 of Set 5 : maralal
# Processing Record 78 of Set 5 : kantang
# Processing Record 79 of Set 5 : alice springs
# Processing Record 80 of Set 5 : katobu
# Processing Record 81 of Set 5 : sirnak
# Processing Record 82 of Set 5 : pahasu
# Processing Record 83 of Set 5 : mangai
# Processing Record 84 of Set 5 : fushun
# Processing Record 85 of Set 5 : coquimbo
# Processing Record 86 of Set 5 : saiha
# City not found. Skipping...
# Processing Record 87 of Set 5 : liverpool
# Processing Record 88 of Set 5 : virginia beach
# Processing Record 89 of Set 5 : bayan
# Processing Record 90 of Set 5 : iralaya
# Processing Record 91 of Set 5 : sri aman
# Processing Record 92 of Set 5 : sicuani
# Processing Record 93 of Set 5 : assiniboia
# Processing Record 94 of Set 5 : khani
# Processing Record 95 of Set 5 : mitsamiouli
# Processing Record 96 of Set 5 : bukama
# Processing Record 97 of Set 5 : cacapava do sul
# Processing Record 98 of Set 5 : anadyr
# Processing Record 99 of Set 5 : bilma
# Processing Record 100 of Set 5 : mercedes
# Processing Record 101 of Set 5 : omsukchan
# Processing Record 0 of Set 6 : poum
# City not found. Skipping...
# Processing Record 1 of Set 6 : kaeo
# Processing Record 2 of Set 6 : mayumba
# Processing Record 3 of Set 6 : nouadhibou
# Processing Record 4 of Set 6 : yumen
# Processing Record 5 of Set 6 : rocha
# Processing Record 6 of Set 6 : creston
# Processing Record 7 of Set 6 : yuryevets
# Processing Record 8 of Set 6 : tineo
# Processing Record 9 of Set 6 : da lat
# Processing Record 10 of Set 6 : san matias
# Processing Record 11 of Set 6 : shahreza
# Processing Record 12 of Set 6 : chilca
# Processing Record 13 of Set 6 : linxia
# Processing Record 14 of Set 6 : riyadh
# Processing Record 15 of Set 6 : beya
# Processing Record 16 of Set 6 : miandrivazo
# Processing Record 17 of Set 6 : liku
# Processing Record 18 of Set 6 : losevo
# Processing Record 19 of Set 6 : americus
# Processing Record 20 of Set 6 : hohhot
# Processing Record 21 of Set 6 : tahe
# Processing Record 22 of Set 6 : santa cruz
# Processing Record 23 of Set 6 : shebunino
# Processing Record 24 of Set 6 : tres picos
# Processing Record 25 of Set 6 : vredendal
# City not found. Skipping...
# Processing Record 26 of Set 6 : nohar
# Processing Record 27 of Set 6 : prince rupert
# Processing Record 28 of Set 6 : black river
# Processing Record 29 of Set 6 : morondava
# Processing Record 30 of Set 6 : northam
# Processing Record 31 of Set 6 : kemalpasa
# Processing Record 32 of Set 6 : khanpur

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

# %%
#Display the DataFrame
weather_df
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Punta Arenas          90      CL  1601221585        81 -53.15  -70.92
# 1           Bluff          93      NZ  1601221586        93 -46.60  168.33
# 2            Lebu           0      CL  1601221290        71 -37.62  -73.65
# 3            Hilo           1      US  1601221586        73  19.73 -155.09
# 4         Rikitea          21      PF  1601221587        83 -23.12 -134.97
# ..            ...         ...     ...         ...       ...    ...     ...
# 537   Black River          20      JM  1601221763        79  18.03  -77.85
# 538     Morondava          50      MG  1601221763        77 -20.28   44.28
# 539       Northam           0      GB  1601221764        77  51.03   -4.22
# 540     Kemalpaşa          20      TR  1601221764        47  38.43   27.42
# 541       Khanpur           0      PK  1601221764        22  28.65   70.66
#
#      Max Temp  Wind Speed
# 0       42.80       14.99
# 1       33.01       14.00
# 2       53.98       10.42
# 3       69.80        6.93
# 4       74.01       12.17
# ..        ...         ...
# 537     86.00       11.41
# 538     77.16       11.72
# 539     60.01       10.00
# 540     80.60       10.29
# 541     91.53        9.55
#
# [542 rows x 9 columns]

# %%
# Export the City_Data into a csv

#weather_df.to_csv("cities.csv")

weather_df.to_csv("cities.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
 #  Get the indices of cities that have humidity over 100%.
weather_df.loc[weather_df["Humidity"] > 100]
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
ax.set_title(' Latitude vs. Max Temperature')
ax.scatter(weather_df['Lat'],weather_df['Max Temp'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_max_temp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
ax.set_title('City Latitude vs. Humidity')
ax.scatter(weather_df['Lat'],weather_df['Humidity'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_humidity.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
ax.set_title('City Latitude vs. Cloudiness')
ax.scatter(weather_df['Lat'],weather_df['Cloudiness'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_cloudiness.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
ax.set_title('City Latitude vs. Wind Speed')
ax.scatter(weather_df['Lat'],weather_df['Wind Speed'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_wind_speed.png')

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_df.loc[weather_df["Lat"] >= 0]
southern_hemisphere = weather_df.loc[weather_df["Lat"] < 0]

# %%
# Define function for creating linear agression and scatter plot
def linear_regression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# 1st Call
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# 2nd Call
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
# Out:
# The r-squared is : -0.86
# Text(0, 0.5, 'Max Temp (F)')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
# Out:
# The r-squared is : -0.08
# Text(0, 0.5, 'Humidity (%)')

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")
# Out:
# The r-squared is : 0.19
# Text(0, 0.5, 'Humidity (%)')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")
# Out:
# The r-squared is : -0.08
# Text(0, 0.5, 'Humidity (%)')

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")
# Out:
# The r-squared is : 0.1
# Text(0, 0.5, 'Cloudiness (%)')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")
# Out:
# The r-squared is : 0.06
# Text(0, 0.5, 'Cloudiness (%)')

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")
# Out:
# The r-squared is : 0.18
# Text(0, 0.5, 'Wind Speed (mph)')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")
# Out:
# The r-squared is : -0.17
# Text(0, 0.5, 'Wind Speed (mph)')
